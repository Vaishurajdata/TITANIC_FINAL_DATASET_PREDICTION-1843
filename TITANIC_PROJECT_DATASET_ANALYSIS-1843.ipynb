# %%
 PROJECT -5  The Titanic Problem is based on the sinking of the ‘Unsinkable’ ship Titanic in early 1912. 
              It gives you information about multiple people like their ages, sexes, sibling counts, 
              embarkment points, and whether or not they survived the disaster. Based on these features,
              you have to predict if an arbitrary passenger on Titanic would survive the sinking or not.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
pd.read_csv(r'D:\Data Trained - Excel links\titanic_train.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Data=pd.read_csv(r'D:\Data Trained - Excel links\titanic_train.csv')

# %%
type(Data)
# Out:
# pandas.core.frame.DataFrame

# %%
Data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
Data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
Data.sample()
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 819          820         0       3  Skoog, Master. Karl Thorsten  male  10.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 819      3      2  347088  27.9   NaN        S

# %%
# index at axis=1
type(Data.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
Data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# NULL VALUES

# %%
Data.isnull().sum().sum()
# Out:
# 866

# %% [markdown]
# IMPUTATION  PROCESS

# %% [markdown]
# - categorical column ==> mode
# - continuous columns== > mean/median

# %%
# Data.fillna()

# %%
Data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Scatterplot:

# %%
 sns.scatterplot()
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x="Survived",y="Pclass",data=Data)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Pclass'>

# %%
sns.scatterplot(x="Survived",y="Sex",data=Data)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Sex'>

# %%
sns.scatterplot(x="Survived",y="Age",data=Data)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.scatterplot(x="Pclass",y="SibSp",data=Data)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='SibSp'>

# %%
sns.scatterplot(x="Survived",y="SibSp",data=Data)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='SibSp'>

# %%
sns.scatterplot(x="Survived",y="Parch",data=Data)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Parch'>

# %%
sns.scatterplot(x="Survived",y="Fare",data=Data)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Fare'>

# %%
sns.scatterplot(x="Pclass",y="Embarked",data=Data)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Embarked'>

# %%
sns.scatterplot(x="Survived",y="Embarked",data=Data)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Embarked'>

# %%
sns.scatterplot(x="PassengerId",y="Pclass",data=Data)
# Out:
# <AxesSubplot:xlabel='PassengerId', ylabel='Pclass'>

# %%
sns.scatterplot(x="Name",y="Age",data=Data)
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Age'>

# %%
sns.scatterplot(x="Name",y="Sex",data=Data)
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Sex'>

# %%
import matplotlib.pyplot as plt
sns.pairplot(Data)
plt.savefig('pairplot.png')
plt.show()

# %% [markdown]
# CORRELATION DATA PREDICTION

# %%
Data.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
Data.corr()['Fare'].sort_values()
# Out:
# Pclass        -0.549500
# PassengerId    0.012658
# Age            0.096067
# SibSp          0.159651
# Parch          0.216225
# Survived       0.257307
# Fare           1.000000
# Name: Fare, dtype: float64

# %% [markdown]
# CONSIDERING HEATMAP :

# %%
import matplotlib.pyplot as plt
# size of canvas
plt.figure(figsize=(22,12))

sns.heatmap(Data.corr(), annot=True, linewidths=0.5,linecolor="black", fmt= '2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# CORRELATION OUTCOME :

# %% [markdown]
# 1.All the columns of the datasets is positively correlated with target column
#
# 2.Survived has 25 percent correlation with the target column which can be considered asa good
#
# 3.SibSp and Prach 41 has 41 percent correlation with the target column which can be considered as a strong
#
# 4.Age has 9 percent correlation with target column which can be considered weak as weak
#
# 5.Fare has 25 percent correlation with taget column which can be considered as good
#
#
# Max correlation:SibSp and Prach
#
# Min correlation: Age

# %% [markdown]
# Descriptive statistics

# %% [markdown]
# Describing Datasets:

# %%
Data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
round(32.204208,2)
# Out:
# 32.2

# %%
round(257.353842,2)
# Out:
# 257.35

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(22,12))
sns.heatmap(round(Data.describe()[1:].transpose(),2),linewidth=2,annot=False,fmt="f")
plt.xticks(fontsize=15)
plt.yticks(fontsize=10)
plt.title("Variable summary")
plt.savefig('heatmap.png')
plt.show()

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# CHECKING FOR OUTLIERS:

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
collist=Data.columns.values
ncol=30
nrows=14

# %%
collist
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
for i in range(0, len(collist)):
    print(collist[i])
    break
# Out:
# PassengerId

# %%
Data[collist[2]]
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
plt.figure(figsize=(ncol,4*ncol))
for i in range (0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data = Data[collist[i]],color ='green',orient ='v')
    plt.tight_layout()

# %% [markdown]
# CHECKING FOR SKEWNESS

# %%
Data.skew()
# Out:
# PassengerId    0.000000
# Survived       0.478523
# Pclass        -0.630548
# Age            0.389108
# SibSp          3.695352
# Parch          2.749117
# Fare           4.787317
# dtype: float64

# %%
 FINDING NORMAL DISTRBUTION CURVE

# %%
sns.distplot(Data["Survived"])
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Density'>

# %%
sns.distplot(Data["Parch"])
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='Density'>

# %%
sns.distplot(Data["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.distplot(Data["SibSp"])
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Density'>

# %%
sns.distplot(Data["Fare"])
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %% [markdown]
# The normal data distribution shows that the data is skewed

# %% [markdown]
# Data cleaning

# %%
Data.corr()['Survived']
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64

# %%
delete=pd.DataFrame([["0.0777221","Age","No","Alot"],["0.035322","SibSp","No","Alot"]],
                    columns=["Correlation with Target","column NAme","Normalised","Outliers"])
delete
# Out:
#   Correlation with Target column NAme Normalised Outliers
# 0               0.0777221         Age         No     Alot
# 1                0.035322       SibSp         No     Alot

# %%
Data=Data.drop(["Age","SibSp"],axis=1)

# %%
Data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Parch  \
# 0                              Braund, Mr. Owen Harris    male      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      0
# 2                               Heikkinen, Miss. Laina  female      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      0
# 4                             Allen, Mr. William Henry    male      0
# ..                                                 ...     ...    ...
# ...

# %% [markdown]
# Removing Outliers:

# %%
## Train-Test Split

# %%
train = Data.iloc[:train_len, :]
test = Data.iloc[:test_len, :]

# %% [markdown]
# MODEL TRAINING

# %%
from sklearn.model_selection import train_test_split
# CLASSIFY COLUMN
def classify(model, x, y):
    x_train, x_test, y_train, y_test= train_test_split(X, Y, test_size=0.25,random_state=42)
    model.fir(x_train, y_train)
    print()

# %% [markdown]
# Z-Score Technique

# %%
np.abs(2)
# Out:
# 2

# %%
np.abs(-2)
# Out:
# 2

# %%
!2 = -1(-2) = 2
!2 = 1(2) = 2
# Out:
# '2' is not recognized as an internal or external command,
# operable program or batch file.
# '2' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# mod of mathematics

# %%
from scipy.stats import zscore

# %%
np.abs(zscore(Data))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17620/868498841.py in <module>
# ----> 1 np.abs(zscore(Data))
#
# ~\anaconda3\lib\site-packages\scipy\stats\stats.py in zscore(a, axis, ddof, nan_policy)
#    2472            [-0.91611681, -0.89090508,  1.4983032 ,  0.88731639, -0.5785977 ]])
#    2473     """
# -> 2474     return zmap(a, a, axis=axis, ddof=ddof, nan_policy=nan_policy)
#    2475
#    2476
#
# ~\anaconda3\lib\site-packages\scipy\stats\stats.py in zmap(scores, compare, axis, ddof, nan_policy)
#    2542             isconst = np.apply_along_axis(_isconst, axis, a)
#    2543     else:
# -> 2544         mn = a.mean(axis=axis, keepdims=True)
#    2545         std = a.std(axis=axis, ddof=ddof, keepdims=True)
#    2546         if axis is None:
#
# ...

# %%
import numpy as np 
z=np.abs(zscore(Data))
z.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17620/2987934823.py in <module>
#       1 import numpy as np
# ----> 2 z=np.abs(zscore(Data))
#       3 z.shape
#
# ~\anaconda3\lib\site-packages\scipy\stats\stats.py in zscore(a, axis, ddof, nan_policy)
#    2472            [-0.91611681, -0.89090508,  1.4983032 ,  0.88731639, -0.5785977 ]])
#    2473     """
# -> 2474     return zmap(a, a, axis=axis, ddof=ddof, nan_policy=nan_policy)
#    2475
#    2476
#
# ~\anaconda3\lib\site-packages\scipy\stats\stats.py in zmap(scores, compare, axis, ddof, nan_policy)
#    2542             isconst = np.apply_along_axis(_isconst, axis, a)
#    2543     else:
# -> 2544         mn = a.mean(axis=axis, keepdims=True)
#    2545         std = a.std(axis=axis, ddof=ddof, keepdims=True)
#    2546         if axis is None:
#
# ...

# %%
---Data went missing----
